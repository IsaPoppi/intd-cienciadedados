# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv("https://raw.githubusercontent.com/WilliBobadilla/datasetmovies/master/movies.csv")

# %%
#visualizando as linhas 
dados.head(76)
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 71                           Beginners   Comedy            Independent
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
dados.columns = ['film','genre','lead_studio','audience_score','Profitability','rotten_tomatoes','worldwide_gross','year']

# %%
#Audience Score
dados.audience_score
# Out:
# 0     70
# 1     52
# 2     35
# 3     44
# 4     72
#       ..
# 72    84
# 73    64
# 74    89
# 75    71
# 76    81
# Name: audience_score, Length: 77, dtype: int64

# %% [markdown]
# # **Medidas Audience Score**

# %%
# Média:
media = np.mean(dados.audience_score)
print("Média:", media)

# Moda,não tem

# Mediana
mediana = np.median(dados.audience_score)
print("Mediana:", mediana)

# Amplitude
amplitude = np.max(dados.audience_score) - np.min(dados.audience_score)
print("Amplitude:", amplitude)

# Desvio médio
desvio_medio = np.mean(np.abs(dados.audience_score - np.mean(dados.audience_score)))
print("Desvio médio:", desvio_medio)

# Desvio médio absoluto
desvio_medio_absoluto = np.median(np.abs(dados.audience_score - np.median(dados.audience_score)))
print("Desvio médio absoluto:", desvio_medio_absoluto)

# Variância
variancia = np.var(dados.audience_score, ddof=1)
print("Variância:", variancia)

# Desvio padrão
desvio_padrao = np.std(dados.audience_score, ddof=1)
print("Desvio padrão:", desvio_padrao)
# Out:
# Média: 63.72727272727273
# Mediana: 64.0
# Amplitude: 54
# Desvio médio: 11.652892561983467
# Desvio médio absoluto: 12.0
# Variância: 186.5167464114833
# Desvio padrão: 13.65711339967137

# %% [markdown]
# # **BoxPlot Audience Score**

# %%
import numpy as np
dados= dados.audience_score

# Primeiro quartil (25%)
q1 = np.percentile(dados, 25)
print("Primeiro quartil:", q1)

# Segundo quartil (50%)
q2 = np.percentile(dados, 50)
print("Segundo quartil (mediana):", q2)

# Terceiro quartil (75%)
q3 = np.percentile(dados, 75)
print("Terceiro quartil:", q3)

# Amplitude interquartil (IQR)
iqr = q3 - q1
print("Amplitude interquartil (IQR):", iqr)

# Limite inferior
lim_inf = q1 - 1.5 * iqr
print("Limite inferior:", lim_inf)

# Limite superior
lim_sup = q3 + 1.5 * iqr
print("Limite superior:", lim_sup)

#para montar o boxplot
import matplotlib.pyplot as plt

plt.boxplot(dados)
plt.show()
# Out:
# Primeiro quartil: 52.0
# Segundo quartil (mediana): 64.0
# Terceiro quartil: 76.0
# Amplitude interquartil (IQR): 24.0
# Limite inferior: 16.0
# Limite superior: 112.0

# %% [markdown]
# ---

# %% [markdown]
# # **Profitability**

# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv("https://raw.githubusercontent.com/WilliBobadilla/datasetmovies/master/movies.csv")

# %%
#visualizando as linhas 
dados.head(76)
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 71                           Beginners   Comedy            Independent
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
dados.columns = ['film','genre','lead studio','audience_score','profitability','rotten_tomatoes','worldwide_gross','year']

# %%
#Profitability
dados.profitability
# Out:
# 0     1.747542
# 1     1.090000
# 2     1.211818
# 3     0.000000
# 4     6.267647
#         ...
# 72    0.652603
# 73    4.382857
# 74    0.448645
# 75    5.343622
# 76    8.096000
# Name: profitability, Length: 77, dtype: float64

# %% [markdown]
# # Medidas

# %%
# Média:
media = np.mean(dados.profitability)
print("Média:", media)

# Moda,não tem

# Mediana
mediana = np.median(dados.profitability)
print("Mediana:", mediana)

# Amplitude
amplitude = np.max(dados.profitability) - np.min(dados.profitability)
print("Amplitude:", amplitude)

# Desvio médio
desvio_medio = np.mean(np.abs(dados.profitability - np.mean(dados.profitability)))
print("Desvio médio:", desvio_medio)

# Desvio médio absoluto
desvio_medio_absoluto = np.median(np.abs(dados.profitability - np.median(dados.profitability)))
print("Desvio médio absoluto:", desvio_medio_absoluto)

# Variância
variancia = np.var(dados.profitability, ddof=1)
print("Variância:", variancia)

# Desvio padrão
desvio_padrao = np.std(dados.profitability, ddof=1)
print("Desvio padrão:", desvio_padrao)
# Out:
# Média: 4.5994833979610386
# Mediana: 2.642352941
# Amplitude: 66.934
# Desvio médio: 3.552957755864396
# Desvio médio absoluto: 1.2766606329999999
# Variância: 64.51286580840836
# Desvio padrão: 8.031990152409822

# %% [markdown]
# # BoxPlot

# %%
import numpy as np
dados= dados.profitability

# Primeiro quartil (25%)
q1 = np.percentile(dados, 25)
print("Primeiro quartil:", q1)

# Segundo quartil (50%)
q2 = np.percentile(dados, 50)
print("Segundo quartil (mediana):", q2)

# Terceiro quartil (75%)
q3 = np.percentile(dados, 75)
print("Terceiro quartil:", q3)

# Amplitude interquartil (IQR)
iqr = q3 - q1
print("Amplitude interquartil (IQR):", iqr)

# Limite inferior
lim_inf = q1 - 1.5 * iqr
print("Limite inferior:", lim_inf)

# Limite superior
lim_sup = q3 + 1.5 * iqr
print("Limite superior:", lim_sup)

#para montar o boxplot
import matplotlib.pyplot as plt

plt.boxplot(dados)
plt.show()
# Out:
# Primeiro quartil: 1.751351351
# Segundo quartil (mediana): 2.642352941
# Terceiro quartil: 5.103116833
# Amplitude interquartil (IQR): 3.3517654819999994
# Limite inferior: -3.2762968719999987
# Limite superior: 10.130765055999998

# %% [markdown]
# ---

# %% [markdown]
# # **Worldwide Gross**

# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv("https://raw.githubusercontent.com/WilliBobadilla/datasetmovies/master/movies.csv")

# %%
#visualizando as linhas 
dados.head(76)
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 71                           Beginners   Comedy            Independent
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
dados.columns = ['film','genre','lead studio','audience_score','profitability','rotten_tomatoes','worldwide_gross','year']
dados['worldwide_gross'] = dados['worldwide_gross'].str.replace('$', '').str.replace(',', '').astype(float)
# Out:
# <ipython-input-188-db2b08bceb43>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados['worldwide_gross'] = dados['worldwide_gross'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
#Worldwide Gross
dados.worldwide_gross
# Out:
# 0      41.94
# 1      19.62
# 2      26.66
# 3      43.04
# 4     219.37
#        ...
# 72     29.37
# 73     30.68
# 74      8.97
# 75    160.31
# 76     60.72
# Name: worldwide_gross, Length: 77, dtype: float64

# %% [markdown]
# # Medidas

# %%
# Média:
media = np.mean(dados.worldwide_gross)
print("Média:", media)

# Moda,não tem

# Mediana
mediana = np.median(dados.worldwide_gross)
print("Mediana:", mediana)

# Amplitude
amplitude = np.max(dados.worldwide_gross) - np.min(dados.worldwide_gross)
print("Amplitude:", amplitude)

# Desvio médio
desvio_medio = np.mean(np.abs(dados.worldwide_gross - np.mean(dados.worldwide_gross)))
print("Desvio médio:", desvio_medio)

# Desvio médio absoluto
desvio_medio_absoluto = np.median(np.abs(dados.worldwide_gross - np.median(dados.worldwide_gross)))
print("Desvio médio absoluto:", desvio_medio_absoluto)

# Variância
variancia = np.var(dados.worldwide_gross, ddof=1)
print("Variância:", variancia)

# Desvio padrão
desvio_padrao = np.std(dados.worldwide_gross, ddof=1)
print("Desvio padrão:", desvio_padrao)
# Out:
# Média: 145.21753246753244
# Mediana: 79.18
# Amplitude: 709.7900000000001
# Desvio médio: 120.28257378984652
# Desvio médio absoluto: 58.470000000000006
# Variância: 26909.172574094326
# Desvio padrão: 164.04015537085525

# %%
import numpy as np
dados = dados.worldwide_gross

# Primeiro quartil (25%)
q1 = np.percentile(dados, 25)
print("Primeiro quartil:", q1)

# Segundo quartil (50%)
q2 = np.percentile(dados, 50)
print("Segundo quartil (mediana):", q2)

# Terceiro quartil (75%)
q3 = np.percentile(dados, 75)
print("Terceiro quartil:", q3)

# Amplitude interquartil (IQR)
iqr = q3 - q1
print("Amplitude interquartil (IQR):", iqr)

# Limite inferior
lim_inf = q1 - 1.5 * iqr
print("Limite inferior:", lim_inf)

# Limite superior
lim_sup = q3 + 1.5 * iqr
print("Limite superior:", lim_sup)

#para montar o boxplot
import matplotlib.pyplot as plt

plt.boxplot(dados)
plt.show()
# Out:
# Primeiro quartil: 32.59
# Segundo quartil (mediana): 79.18
# Terceiro quartil: 205.3
# Amplitude interquartil (IQR): 172.71
# Limite inferior: -226.475
# Limite superior: 464.365

# %% [markdown]
# # **Rotten Tomatoes**

# %%
import pandas as pd
import numpy as np

# %%
dados = pd.read_csv("https://raw.githubusercontent.com/WilliBobadilla/datasetmovies/master/movies.csv")

# %%
#visualizando as linhas 
dados.head(76)
# Out:
#                                   Film    Genre            Lead Studio  \
# 0           Zack and Miri Make a Porno  Romance  The Weinstein Company
# 1                      Youth in Revolt   Comedy  The Weinstein Company
# 2   You Will Meet a Tall Dark Stranger   Comedy            Independent
# 3                         When in Rome   Comedy                 Disney
# 4                What Happens in Vegas   Comedy                    Fox
# ..                                 ...      ...                    ...
# 71                           Beginners   Comedy            Independent
# 72                 Across the Universe  romance            Independent
# 73                       A Serious Man    Drama              Universal
# 74                  A Dangerous Method    Drama            Independent
# 75                          27 Dresses   Comedy                    Fox
#
#     Audience score %  Profitability  Rotten Tomatoes % Worldwide Gross  Year
# ...

# %%
dados.columns = ['film','genre','lead studio','audience_score','profitability','rotten_tomatoes','worldwide_gross','year']

# %%
#Rotten Tomatoes
dados.rotten_tomatoes
# Out:
# 0     64
# 1     68
# 2     43
# 3     15
# 4     28
#       ..
# 72    54
# 73    89
# 74    79
# 75    40
# 76    87
# Name: rotten_tomatoes, Length: 77, dtype: int64

# %% [markdown]
# # Medidas

# %%
# Média:
media = np.mean(dados.rotten_tomatoes)
print("Média:", media)

# Moda,não tem

# Mediana
mediana = np.median(dados.rotten_tomatoes)
print("Mediana:", mediana)

# Amplitude
amplitude = np.max(dados.rotten_tomatoes) - np.min(dados.rotten_tomatoes)
print("Amplitude:", amplitude)

# Desvio médio
desvio_medio = np.mean(np.abs(dados.rotten_tomatoes - np.mean(dados.rotten_tomatoes)))
print("Desvio médio:", desvio_medio)

# Desvio médio absoluto
desvio_medio_absoluto = np.median(np.abs(dados.rotten_tomatoes - np.median(dados.rotten_tomatoes)))
print("Desvio médio absoluto:", desvio_medio_absoluto)

# Variância
variancia = np.var(dados.rotten_tomatoes, ddof=1)
print("Variância:", variancia)

# Desvio padrão
desvio_padrao = np.std(dados.rotten_tomatoes, ddof=1)
print("Desvio padrão:", desvio_padrao)
# Out:
# Média: 46.701298701298704
# Mediana: 45.0
# Amplitude: 93
# Desvio médio: 21.949401248102543
# Desvio médio absoluto: 19.0
# Variância: 680.949077238551
# Desvio padrão: 26.095001000930257

# %% [markdown]
# # Boxplot

# %%
import numpy as np
dados = dados.rotten_tomatoes

# Primeiro quartil (25%)
q1 = np.percentile(dados, 25)
print("Primeiro quartil:", q1)

# Segundo quartil (50%)
q2 = np.percentile(dados, 50)
print("Segundo quartil (mediana):", q2)

# Terceiro quartil (75%)
q3 = np.percentile(dados, 75)
print("Terceiro quartil:", q3)

# Amplitude interquartil (IQR)
iqr = q3 - q1
print("Amplitude interquartil (IQR):", iqr)

# Limite inferior
lim_inf = q1 - 1.5 * iqr
print("Limite inferior:", lim_inf)

# Limite superior
lim_sup = q3 + 1.5 * iqr
print("Limite superior:", lim_sup)

#para montar o boxplot
import matplotlib.pyplot as plt

plt.boxplot(dados)
plt.show()
# Out:
# Primeiro quartil: 26.0
# Segundo quartil (mediana): 45.0
# Terceiro quartil: 64.0
# Amplitude interquartil (IQR): 38.0
# Limite inferior: -31.0
# Limite superior: 121.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Contar a quantidade de filmes por gênero
contagem_genero = dados['genre'].value_counts()

# Criar o gráfico de pizza
plt.pie(contagem_genero, labels=contagem_genero.index, autopct='%1.1f%%')

# Personalizar o gráfico (opcional)
plt.title('Distribuição dos Gêneros de Filmes')

# Exibir o gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Contar a quantidade de filmes por estúdio principal
contagem_estudio = dados['lead_studio'].value_counts()

# Criar o gráfico de pizza
plt.pie(contagem_estudio, labels=contagem_estudio.index, autopct='%1.1f%%')

# Personalizar o gráfico (opcional)
plt.title('Distribuição dos Estúdios Principais')

# Exibir o gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Filtrar valores ausentes
dados = dados.dropna(subset=['audience_score'])

# Ordenar os dados pelo audience_score
dados = dados.sort_values(by='audience_score', ascending=False)

# Selecionar os 10 filmes com maior audience_score
top_10_filmes = dados.head(10)

# Criar o gráfico de barras
plt.bar(top_10_filmes['film'], top_10_filmes['audience_score'])

# Personalizar o gráfico
plt.title('Top 10 Filmes com Maior Número de Audiência')
plt.xlabel('Filme')
plt.ylabel('Audience Score')

# Rotacionar os rótulos do eixo x
plt.xticks(rotation=90)

# Exibir o gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Filtrar valores ausentes
dados = dados.dropna(subset=['rotten_tomatoes'])

# Criar o gráfico de dispersão
plt.scatter(dados['rotten_tomatoes'], dados['audience_score'])

# Personalizar o gráfico
plt.title('Pontuação do Rotten Tomatoes vs. Pontuação do Público')
plt.xlabel('Rotten Tomatoes')
plt.ylabel('Pontuação do Público')

# Exibir o gráfico
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filtrar os principais anos
principais_anos = dados['year'].value_counts().head(5)

# Criar o gráfico de pizza
plt.pie(principais_anos, labels=principais_anos.index, autopct='%1.1f%%')

# Personalizar o gráfico
plt.title('Distribuição dos Principais Anos')
plt.axis('equal')

# Exibir o gráfico
plt.show()
